# %%
import pandas as pd

data_source = "/home/fra/DataMart/datacentre/opendata/UCI/"
train_file = "adult_train.csv"
test_file = "adult_test.csv"

# load data
trainData = pd.read_csv(data_source + train_file)
trainData.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
import sys
mylib = '/home/fra/Project/pyProj/mlib'

# %%
sys.path.append(mylib)

# %%
import transform as trf
import pipeline as pl

# %%
target_col = 'INCOME'

# %% [markdown]
# ### Pipeline

# %%
tpipeline = pl.make_target_pipeline(target_col)
y = tpipeline.fit_transform(trainData)

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
trainData.shape
# Out:
# (32561, 15)

# %%
# exclude target
X = trainData.iloc[:,:14]

# %%
X
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ### WOE: for binary target only

# %%
from category_encoders.woe import WOEEncoder

# %%
out = WOEEncoder().fit_transform(X, y)
# Out:
# /home/fra/.pyenv/versions/pyml/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
out
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39   0.165126   77516   0.803851             13       -1.882906
# 1       50   0.228752   83311   0.803851             13        0.934688
# 2       38  -0.125200  215646  -0.513333              9       -1.001332
# 3       53  -0.125200  234721  -1.758560              7        0.934688
# 4       28  -0.125200  338409   0.803851             13        0.934688
# ...    ...        ...     ...        ...            ...             ...
# 32556   27  -0.125200  257302   0.043214             12        0.934688
# 32557   40  -0.125200  154374  -0.513333              9        0.934688
# 32558   58  -0.125200  151910  -0.513333              9       -1.209926
# 32559   22  -0.125200  201490  -0.513333              9       -1.882906
# 32560   52   1.378061  287927  -0.513333              9        0.934688
#
#        occupation  relationship      race       sex  capital_gain  \
# ...

# %% [markdown]
# ### Profiler

# %%
from varprofile import Profiler

# %%
profiler = Profiler(trainData, 'income')

# %%
profiler.get_categorical_column()
# Out:
# ['workclass',
#  'relationship',
#  'education',
#  'marital_status',
#  'occupation',
#  'income',
#  'race',
#  'native_country',
#  'sex']

# %%
profiler.get_woe('race', categorical=True)
# Out:
# race
#  Amer-Indian-Eskimo   -0.885006
#  Asian-Pac-Islander    0.131389
#  Black                -0.807947
#  Other                -1.138209
#  White                 0.080647
# Name:  >50K, dtype: float64

# %%
profiler.get_woe('sex', categorical=True)
# Out:
# sex
#  Female   -0.948017
#  Male      0.328119
# Name:  >50K, dtype: float64

# %%
profiler.get_woe('occupation', categorical=True)
# Out:
# occupation
#  ?                   -1.009222
#  Adm-clerical        -0.713645
#  Armed-Forces        -0.931195
#  Craft-repair        -0.079132
#  Exec-managerial      1.084280
#  Farming-fishing     -0.885607
#  Handlers-cleaners   -1.555142
#  Machine-op-inspct   -0.798806
#  Other-service       -1.989467
#  Priv-house-serv     -3.848966
#  Prof-specialty       0.943671
#  Protective-serv      0.417885
#  Sales                0.150146
#  Tech-support         0.324443
#  Transport-moving    -0.235702
# Name:  >50K, dtype: float64

# %%
profiler.count_unique_values()
# Out:
# {'age': 73,
#  'workclass': 9,
#  'fnlwgt': 21648,
#  'education': 16,
#  'education_num': 16,
#  'marital_status': 7,
#  'occupation': 15,
#  'relationship': 6,
#  'race': 5,
#  'sex': 2,
#  'capital_gain': 119,
#  'capital_loss': 92,
#  'hours_per_week': 94,
#  'native_country': 42,
#  'income': 2}
