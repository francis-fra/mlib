# %%
import os, sys
import pandas as pd

# %%
sys.path.append('..')

# %%
import explore as ex

# %%
data_file = "abalone.csv"
df = pd.read_csv("../data/"+data_file)

# %%
df.head()
# Out:
#   sex  length  diameter  height  whole_wt  shucked_wt  viscera_wt  shell_wt  \
# 0   M   0.455     0.365   0.095    0.5140      0.2245      0.1010     0.150
# 1   M   0.350     0.265   0.090    0.2255      0.0995      0.0485     0.070
# 2   F   0.530     0.420   0.135    0.6770      0.2565      0.1415     0.210
# 3   M   0.440     0.365   0.125    0.5160      0.2155      0.1140     0.155
# 4   I   0.330     0.255   0.080    0.2050      0.0895      0.0395     0.055
#
#    rings
# 0     15
# 1      7
# 2      9
# 3     10
# 4      7

# %% [markdown]
# ### Data types

# %%
ex.get_type_dict(df)
# Out:
# {'float64': ['length',
#   'diameter',
#   'height',
#   'whole_wt',
#   'shucked_wt',
#   'viscera_wt',
#   'shell_wt'],
#  'int64': ['rings'],
#  'object': ['sex']}

# %%
ex.get_column_type(df)
# Out:
# {'binary': [],
#  'categorical': ['sex'],
#  'numerical': ['shucked_wt',
#   'height',
#   'viscera_wt',
#   'diameter',
#   'whole_wt',
#   'length',
#   'rings',
#   'shell_wt']}

# %%
ex.get_type_tuple(df)
# Out:
# [('sex', dtype('O')),
#  ('length', dtype('float64')),
#  ('diameter', dtype('float64')),
#  ('height', dtype('float64')),
#  ('whole_wt', dtype('float64')),
#  ('shucked_wt', dtype('float64')),
#  ('viscera_wt', dtype('float64')),
#  ('shell_wt', dtype('float64')),
#  ('rings', dtype('int64'))]

# %%
ex.get_categorical_column(df)
# Out:
# ['sex']

# %%
ex.get_non_categorical_column(df)
# Out:
# ['shucked_wt',
#  'height',
#  'viscera_wt',
#  'diameter',
#  'whole_wt',
#  'length',
#  'rings',
#  'shell_wt']

# %%
ex.get_numerical_column(df)
# Out:
# ['length',
#  'diameter',
#  'height',
#  'whole_wt',
#  'shucked_wt',
#  'viscera_wt',
#  'shell_wt',
#  'rings']

# %% [markdown]
# ### Counting

# %%
from imp import reload

# %%
reload(ex)
# Out:
# <module 'explore' from '../explore.py'>

# %%
df['sex'].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
ex.count_unique_values(df)
# Out:
# {'sex': 3,
#  'length': 134,
#  'diameter': 111,
#  'height': 51,
#  'whole_wt': 2429,
#  'shucked_wt': 1515,
#  'viscera_wt': 880,
#  'shell_wt': 926,
#  'rings': 28}

# %%
d = ex.get_distinct_value(df)

# %%
d
# Out:
# {'sex': array(['M', 'F', 'I'], dtype=object),
#  'length': array([0.455, 0.35 , 0.53 , 0.44 , 0.33 , 0.425, 0.545, 0.475, 0.55 ,
#         0.525, 0.43 , 0.49 , 0.535, 0.47 , 0.5  , 0.355, 0.365, 0.45 ,
#         0.38 , 0.565, 0.615, 0.56 , 0.58 , 0.59 , 0.605, 0.575, 0.68 ,
#         0.665, 0.705, 0.465, 0.54 , 0.24 , 0.205, 0.21 , 0.39 , 0.46 ,
#         0.325, 0.52 , 0.4  , 0.485, 0.405, 0.445, 0.245, 0.505, 0.595,
#         0.31 , 0.555, 0.57 , 0.6  , 0.62 , 0.625, 0.695, 0.36 , 0.51 ,
#         0.435, 0.495, 0.385, 0.515, 0.37 , 0.27 , 0.375, 0.7  , 0.71 ,
#         0.265, 0.305, 0.345, 0.65 , 0.28 , 0.175, 0.17 , 0.635, 0.645,
#         0.61 , 0.725, 0.235, 0.315, 0.225, 0.64 , 0.63 , 0.585, 0.42 ,
#         0.335, 0.415, 0.275, 0.295, 0.075, 0.13 , 0.11 , 0.16 , 0.23 ,
#         0.3  , 0.32 , 0.655, 0.66 , 0.2  , 0.165, 0.19 , 0.74 , 0.34 ,
#         0.675, 0.745, 0.685, 0.69 , 0.67 , 0.29 , 0.26 , 0.395, 0.41 ,
# ...

# %%
d['sex']
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
get_distinct_value(df, 'sex')
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
ex.count_levels(df, ['sex'])
# Out:
# {'sex': [('F', 1307), ('I', 1342), ('M', 1528)]}

# %%
ex.count_missing(df)
# Out:
# {'sex': 0,
#  'length': 0,
#  'diameter': 0,
#  'height': 0,
#  'whole_wt': 0,
#  'shucked_wt': 0,
#  'viscera_wt': 0,
#  'shell_wt': 0,
#  'rings': 0}

# %%
ex.summary(df)
# Out:
#             unique_values  num_missing  numerical  categorical  binary
# sex                     3            0      False         True   False
# length                134            0       True        False   False
# diameter              111            0       True        False   False
# height                 51            0       True        False   False
# whole_wt             2429            0       True        False   False
# shucked_wt           1515            0       True        False   False
# viscera_wt            880            0       True        False   False
# shell_wt              926            0       True        False   False
# rings                  28            0       True        False   False
